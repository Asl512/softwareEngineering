# %%
# !pip install transformers

# %%
from transformers import pipeline

classifier = pipeline("sentiment-analysis", "blanchefort/rubert-base-cased-sentiment") # базовый

classifier("Этот фильм был ужасен! Время потрачено впустую!")
# Out:
# ...
# [{'label': 'NEGATIVE', 'score': 0.7515999674797058}]

# %%
classifier = pipeline("sentiment-analysis", "blanchefort/rubert-base-cased-sentiment-med") #для анализа настроений медицинских обзоров

# %%
classifier("Вы беременны")
# Out:
# [{'label': 'POSITIVE', 'score': 0.8124520182609558}]

# %%
classifier = pipeline("sentiment-analysis", "blanchefort/rubert-base-cased-sentiment-rusentiment") #

# %%
classifier("Не бойся, я рядом")
# Out:
# [{'label': 'POSITIVE', 'score': 0.8085383772850037}]

# %%
classifier("Мне не нравится твое поведение")
# Out:
# [{'label': 'NEUTRAL', 'score': 0.625221312046051}]

# %%
classifier = pipeline("sentiment-analysis", "blanchefort/rubert-base-cased-sentiment-rurewiews") #отзывы о товарах

# %%
classifier("Этот предмет позволит нам выбраться в люди!")
# Out:
# [{'label': 'NEUTRAL', 'score': 0.5408925414085388}]

# %%
classifier("Качество плохое, но доставка быстрая")
# Out:
# [{'label': 'LABEL_1', 'score': 0.5634927153587341}]

# %%
classifier = pipeline("sentiment-analysis", "blanchefort/rubert-base-cased-sentiment-mokoron") #RuTweetCorp

# %%
#LABEL_0 - Позитивное сообщение
#LABEL_1 - Негативное сообщение
classifier("Сегодня будет ужасный день, в прекрасную погоду")
# Out:
# [{'label': 'LABEL_1', 'score': 0.5890159606933594}]

# %%
classifier("Желаю тебе счастья")
# Out:
# [{'label': 'LABEL_0', 'score': 0.5433152318000793}]
